# %% [markdown]
# **1. Define Covariance and explain how it differs from Correlation in terms of scale and interpretation.**
#
# - covariance may be defined as those which measures the relation between two numerical values and it mainly measures how the numerical value changes together that means it only tells about the direction not the strength of the relation.
#
# - difference between covariance and coorelation on the basis of scale and interpretation
#
# covariance only measures the direction of the relation that is whether it is positive or negative while corelation tells about both the direction and the strength of the relation
#
# and in terms of interpretation covariance value is bigger and difficult to interprate along with that covariance has unrealistc unit and also does not has standarised value
#
#   while
#
#   correlation has standarised value and it ius unit free hense it is easy to interprate
#
#   **2. What does a positive, negative, and zero covariance indicate about the relationship between two variables?**
#
#   - Positive covariance tells aboutb the direct relation bet the two variables that means if one is increasing the other is also increasing
#
#   - Negative covariance tells about indirect relation between two variables that means if one is increasing the other variable is decreasing
#
#   - Zero covariance generally tells about there is no relation bet the two variables
#
#
#   **Q3. Discuss the limitations of covariance as a measure of relationship between two variables. Why is correlation**
# **preferred in many cases?**
#
# - The limitation of correlation are
#
#  it does not has standarized value that makes it difficult to interprate and
#
#  the unit of covariance is unrealistic ,
#
#
#  and correlation is prefered because it is very easy to interprate as it has standarized value that varies from -1 to 1 and also it has no unit.
#
#  **4.Explain the difference between Pearson’s correlation coefficient and Spearman’s rank correlation**
# **coefficient. When would you prefer to use Spearman’s correlation?**
#
# - The main differences are of the nature of relationship and the type of data they handle
#
# Pearson correlation it mainly measures linear relationships( straight line)
#
# and the type of data they handle are continuous interval/ ratio data (eg. height,weight)
#
# and Spearman's Rank correlation mainly measures monotonic reltion( increasing, decreasing trend) not necessarily straight line
#
# and mostly works with ordinal data .
#
# - we would prefer spearman's correlation when-
#
# non-linear but monotonic relation
#
# and there is ordinal data , and presence of outliers along with non normal distribution
#
# **5. If the correlation coefficient between two variables X and Y is 0.85, interpret this value in context. Can you**
# **infer causation from this value? Why or why not?**
#
# - here the correlation coefficient between Xand Y is 0.85 that ,means it is a strong positive relationship between these two values
#
# that means it is directly proportional to each other eg.- if one will increase the other will increase
#
# here it does not tell about the causation because the means if one thing directly causes other then there will be causation but here is only the relatioj between the variables
#
#
# **6. Using the dataset below, calculate the covariance between X and Y.**
#
# for this first we need to find out the mean  of both the variables and then calculate the deviation and product and then sum of all the products after that devide it with 4
#
# hense final calculation ois cov(x,y) =19/4= 4.75
#
# **7. Compute the Pearson correlation coefficient between variables A and B:**
#
# For this we need to find out the cov(a,b) and devide it with the standared deviation of both the variables
#
# hense the final value is =0.99
#
# that means it is strongly positive relationship ....
#
# **8. The following table shows heights (in cm) and weights (in kg) of 5 students.**
# **Find the correlation coefficient between Height and Weight.**
#
# Mean of height is =164
# mean of weight =58
#
# and after applying formula the value of coorelation is = **0.996** that means it is a strong positive relationship between the variables
#
# **9.Given the dataset below, determine whether there is a positive or negative correlation between X and Y.**
# (No need for exact calculation, just reasoning.)
#
# here in this table if **x** is increasing the value of **y** is decreasing hense there is indirect relationship bet both the variables that means it has **negative realtion**
#
# **10. Two investment portfolios have the following returns (%) over 5 years. Compute the covariance and**
# **correlation coefficient, and interpret whether the portfolios move together.**
#
# Here covariance value is after applying formula =3 a positive 3
#
# and correlation coefficient is =0.98
#
# that means it is showing that is has strong positive relation and here 3 showing the portfolio A and B will show or move in same direction
